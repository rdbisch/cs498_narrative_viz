# %% [markdown]
# * Import
# by Rick Bischoff 7/18/2020
#
# The files came in an ordered directory hierarchy in NetCDF4 format.  The code below leverages this hierarchy to traverse the directory structure and restate the files in a format that is easily parseable by javascript.
#
# Specifically, the raw data is in the format (in directory ../raw/):
#
#     <cropName>/yield_<year>.nc4
#
# and the data inside the NetCDF file is in the format
#
#     var[lat, lon] = yield
#
# We will convert all of these files into one massive csv file that looks like this:
#
#     crop,year,lat,lon,yield
#
# and also will remove missing values in the process.

# %%
from netCDF4 import Dataset
from itertools import repeat
import re
import pandas as pd

# %%
files = ["../raw/wheat_winter/yield_2016.nc4"]

# %%
files = []
import os
import sys

walk_dir = "../raw/"

for root, subdirs, _files in os.walk(walk_dir):
    for filename in _files:
        if filename.find("nc4") != -1:
            files.append(os.path.join(root, filename))

print("{0} files found.".format(len(files)))
# Out:
# 360 files found.

# %%
fileparse = re.compile(r"\.\./raw/(\w+)/([A-Za-z]+)_(\d+)\.nc4")

crops = []
years = []
variables = []
lats = [] # do you even lift
lons = []
values = []

for f in files:
    (crop, var, year) = fileparse.match(f).groups()

    rootgrp = Dataset(f, "r")
    lat_array = rootgrp.variables["lat"][:].data
    lat_N = lat_array.shape[0]
    lon_array = rootgrp.variables["lon"][:].data
    lon_N = lon_array.shape[0]
    val_tmp = rootgrp.variables["var"][:]
    missing = val_tmp.fill_value
    val_array = val_tmp.data
    
    rows_added = 0
    rows_skip = 0
    for lat in range(lat_N):
        for lon in range(lon_N):
            if val_array[lat, lon] == missing:
                rows_skip += 1
            else:
                rows_added += 1
                values.append(val_array[lat][lon])
                lats.append(lat_array[lat])
                lons.append(lon_array[lon])

    print("{0}\trows {1}\tskip {2}".format((crop,var,year), rows_added, rows_skip))
    crops.extend(repeat(crop, rows_added))
    years.extend(repeat(year, rows_added))
    variables.extend(repeat(var, rows_added))

data = pd.DataFrame({
    "crops": crops,
    "years": years,
    "measure": variables,
    "lat": lats,
    "lon": lons,
    "value": values
})
data.to_csv("../data.csv")
# Out:
# ('maize', 'yield', '1981')	rows 5228	skip 253972
# ('maize', 'yield', '1982')	rows 15032	skip 244168
# ('maize', 'yield', '1983')	rows 15034	skip 244166
# ('maize', 'yield', '1984')	rows 15027	skip 244173
# ('maize', 'yield', '1985')	rows 15032	skip 244168
# ('maize', 'yield', '1986')	rows 15040	skip 244160
# ('maize', 'yield', '1987')	rows 15075	skip 244125
# ('maize', 'yield', '1988')	rows 15087	skip 244113
# ('maize', 'yield', '1989')	rows 15072	skip 244128
# ('maize', 'yield', '1990')	rows 15078	skip 244122
# ('maize', 'yield', '1991')	rows 15087	skip 244113
# ('maize', 'yield', '1992')	rows 15090	skip 244110
# ('maize', 'yield', '1993')	rows 14828	skip 244372
# ('maize', 'yield', '1994')	rows 15080	skip 244120
# ('maize', 'yield', '1995')	rows 15081	skip 244119
# ('maize', 'yield', '1996')	rows 15077	skip 244123
# ('maize', 'yield', '1997')	rows 15080	skip 244120
# ('maize', 'yield', '1998')	rows 15099	skip 244101
# ('maize', 'yield', '1999')	rows 15083	skip 244117
# ('maize', 'yield', '2000')	rows 15079	skip 244121
# ('maize', 'yield', '2001')	rows 15079	skip 244121
# ('maize', 'yield', '2002')	rows 15079	skip 244121
# ('maize', 'yield', '2003')	rows 15080	skip 244120
# ('maize', 'yield', '2004')	rows 15088	skip 244112
# ('maize', 'yield', '2005')	rows 15088	skip 244112
# ('maize', 'yield', '2006')	rows 15082	skip 244118
# ('maize', 'yield', '2007')	rows 15087	skip 244113
# ('maize', 'yield', '2008')	rows 15078	skip 244122
# ('maize', 'yield', '2009')	rows 15079	skip 244121
# ('maize', 'yield', '2010')	rows 15086	skip 244114
# ('maize', 'yield', '2011')	rows 12717	skip 246483
# ('maize', 'yield', '2012')	rows 12717	skip 246483
# ('maize', 'yield', '2013')	rows 12717	skip 246483
# ('maize', 'yield', '2014')	rows 12717	skip 246483
# ('maize', 'yield', '2015')	rows 11135	skip 248065
# ('maize', 'yield', '2016')	rows 12717	skip 246483
# ('maize_major', 'yield', '1981')	rows 4772	skip 254428
# ('maize_major', 'yield', '1982')	rows 15025	skip 244175
# ('maize_major', 'yield', '1983')	rows 15024	skip 244176
# ('maize_major', 'yield', '1984')	rows 15017	skip 244183
# ('maize_major', 'yield', '1985')	rows 15020	skip 244180
# ('maize_major', 'yield', '1986')	rows 15034	skip 244166
# ('maize_major', 'yield', '1987')	rows 15065	skip 244135
# ('maize_major', 'yield', '1988')	rows 15080	skip 244120
# ('maize_major', 'yield', '1989')	rows 15060	skip 244140
# ('maize_major', 'yield', '1990')	rows 15067	skip 244133
# ('maize_major', 'yield', '1991')	rows 15074	skip 244126
# ('maize_major', 'yield', '1992')	rows 15078	skip 244122
# ('maize_major', 'yield', '1993')	rows 14819	skip 244381
# ('maize_major', 'yield', '1994')	rows 15073	skip 244127
# ('maize_major', 'yield', '1995')	rows 15066	skip 244134
# ('maize_major', 'yield', '1996')	rows 15064	skip 244136
# ('maize_major', 'yield', '1997')	rows 15070	skip 244130
# ('maize_major', 'yield', '1998')	rows 15091	skip 244109
# ('maize_major', 'yield', '1999')	rows 15072	skip 244128
# ('maize_major', 'yield', '2000')	rows 15072	skip 244128
# ('maize_major', 'yield', '2001')	rows 15068	skip 244132
# ('maize_major', 'yield', '2002')	rows 15070	skip 244130
# ('maize_major', 'yield', '2003')	rows 15075	skip 244125
# ('maize_major', 'yield', '2004')	rows 15075	skip 244125
# ('maize_major', 'yield', '2005')	rows 15076	skip 244124
# ('maize_major', 'yield', '2006')	rows 15072	skip 244128
# ('maize_major', 'yield', '2007')	rows 15077	skip 244123
# ('maize_major', 'yield', '2008')	rows 15070	skip 244130
# ('maize_major', 'yield', '2009')	rows 15065	skip 244135
# ('maize_major', 'yield', '2010')	rows 15072	skip 244128
# ('maize_major', 'yield', '2011')	rows 12716	skip 246484
# ('maize_major', 'yield', '2012')	rows 12716	skip 246484
# ('maize_major', 'yield', '2013')	rows 12716	skip 246484
# ('maize_major', 'yield', '2014')	rows 12716	skip 246484
# ('maize_major', 'yield', '2015')	rows 10925	skip 248275
# ('maize_major', 'yield', '2016')	rows 12716	skip 246484
# ('maize_second', 'yield', '1981')	rows 910	skip 258290
# ('maize_second', 'yield', '1982')	rows 3012	skip 256188
# ('maize_second', 'yield', '1983')	rows 3007	skip 256193
# ('maize_second', 'yield', '1984')	rows 3014	skip 256186
# ('maize_second', 'yield', '1985')	rows 3016	skip 256184
# ('maize_second', 'yield', '1986')	rows 3007	skip 256193
# ('maize_second', 'yield', '1987')	rows 3018	skip 256182
# ('maize_second', 'yield', '1988')	rows 3014	skip 256186
# ('maize_second', 'yield', '1989')	rows 3017	skip 256183
# ('maize_second', 'yield', '1990')	rows 3015	skip 256185
# ('maize_second', 'yield', '1991')	rows 3014	skip 256186
# ('maize_second', 'yield', '1992')	rows 3009	skip 256191
# ('maize_second', 'yield', '1993')	rows 3009	skip 256191
# ('maize_second', 'yield', '1994')	rows 3016	skip 256184
# ('maize_second', 'yield', '1995')	rows 3007	skip 256193
# ('maize_second', 'yield', '1996')	rows 3012	skip 256188
# ('maize_second', 'yield', '1997')	rows 3002	skip 256198
# ('maize_second', 'yield', '1998')	rows 3020	skip 256180
# ('maize_second', 'yield', '1999')	rows 3011	skip 256189
# ('maize_second', 'yield', '2000')	rows 3018	skip 256182
# ('maize_second', 'yield', '2001')	rows 3011	skip 256189
# ('maize_second', 'yield', '2002')	rows 3011	skip 256189
# ('maize_second', 'yield', '2003')	rows 3014	skip 256186
# ('maize_second', 'yield', '2004')	rows 3020	skip 256180
# ('maize_second', 'yield', '2005')	rows 3007	skip 256193
# ('maize_second', 'yield', '2006')	rows 3007	skip 256193
# ('maize_second', 'yield', '2007')	rows 3010	skip 256190
# ('maize_second', 'yield', '2008')	rows 3013	skip 256187
# ('maize_second', 'yield', '2009')	rows 3009	skip 256191
# ('maize_second', 'yield', '2010')	rows 3012	skip 256188
# ('maize_second', 'yield', '2011')	rows 2521	skip 256679
# ('maize_second', 'yield', '2012')	rows 2521	skip 256679
# ('maize_second', 'yield', '2013')	rows 2521	skip 256679
# ('maize_second', 'yield', '2014')	rows 2521	skip 256679
# ('maize_second', 'yield', '2015')	rows 2241	skip 256959
# ('maize_second', 'yield', '2016')	rows 2521	skip 256679
# ('rice', 'yield', '1981')	rows 3568	skip 255632
# ('rice', 'yield', '1982')	rows 9551	skip 249649
# ('rice', 'yield', '1983')	rows 9545	skip 249655
# ('rice', 'yield', '1984')	rows 9544	skip 249656
# ('rice', 'yield', '1985')	rows 9547	skip 249653
# ('rice', 'yield', '1986')	rows 9553	skip 249647
# ('rice', 'yield', '1987')	rows 9548	skip 249652
# ('rice', 'yield', '1988')	rows 9553	skip 249647
# ('rice', 'yield', '1989')	rows 9547	skip 249653
# ('rice', 'yield', '1990')	rows 9550	skip 249650
# ('rice', 'yield', '1991')	rows 9557	skip 249643
# ('rice', 'yield', '1992')	rows 9548	skip 249652
# ('rice', 'yield', '1993')	rows 9555	skip 249645
# ('rice', 'yield', '1994')	rows 9551	skip 249649
# ('rice', 'yield', '1995')	rows 9548	skip 249652
# ('rice', 'yield', '1996')	rows 9560	skip 249640
# ('rice', 'yield', '1997')	rows 9554	skip 249646
# ('rice', 'yield', '1998')	rows 9558	skip 249642
# ('rice', 'yield', '1999')	rows 9559	skip 249641
# ('rice', 'yield', '2000')	rows 9557	skip 249643
# ('rice', 'yield', '2001')	rows 9545	skip 249655
# ('rice', 'yield', '2002')	rows 9550	skip 249650
# ('rice', 'yield', '2003')	rows 9558	skip 249642
# ('rice', 'yield', '2004')	rows 9538	skip 249662
# ('rice', 'yield', '2005')	rows 9546	skip 249654
# ('rice', 'yield', '2006')	rows 9552	skip 249648
# ('rice', 'yield', '2007')	rows 9559	skip 249641
# ('rice', 'yield', '2008')	rows 9557	skip 249643
# ('rice', 'yield', '2009')	rows 9553	skip 249647
# ('rice', 'yield', '2010')	rows 9556	skip 249644
# ('rice', 'yield', '2011')	rows 8185	skip 251015
# ('rice', 'yield', '2012')	rows 8185	skip 251015
# ('rice', 'yield', '2013')	rows 8173	skip 251027
# ('rice', 'yield', '2014')	rows 8173	skip 251027
# ('rice', 'yield', '2015')	rows 7415	skip 251785
# ('rice', 'yield', '2016')	rows 8173	skip 251027
# ('rice_major', 'yield', '1981')	rows 3146	skip 256054
# ('rice_major', 'yield', '1982')	rows 9546	skip 249654
# ('rice_major', 'yield', '1983')	rows 9540	skip 249660
# ('rice_major', 'yield', '1984')	rows 9538	skip 249662
# ('rice_major', 'yield', '1985')	rows 9542	skip 249658
# ('rice_major', 'yield', '1986')	rows 9548	skip 249652
# ('rice_major', 'yield', '1987')	rows 9543	skip 249657
# ('rice_major', 'yield', '1988')	rows 9549	skip 249651
# ('rice_major', 'yield', '1989')	rows 9542	skip 249658
# ('rice_major', 'yield', '1990')	rows 9545	skip 249655
# ('rice_major', 'yield', '1991')	rows 9552	skip 249648
# ('rice_major', 'yield', '1992')	rows 9543	skip 249657
# ('rice_major', 'yield', '1993')	rows 9550	skip 249650
# ('rice_major', 'yield', '1994')	rows 9546	skip 249654
# ('rice_major', 'yield', '1995')	rows 9544	skip 249656
# ('rice_major', 'yield', '1996')	rows 9556	skip 249644
# ('rice_major', 'yield', '1997')	rows 9549	skip 249651
# ('rice_major', 'yield', '1998')	rows 9554	skip 249646
# ('rice_major', 'yield', '1999')	rows 9555	skip 249645
# ('rice_major', 'yield', '2000')	rows 9553	skip 249647
# ('rice_major', 'yield', '2001')	rows 9541	skip 249659
# ('rice_major', 'yield', '2002')	rows 9545	skip 249655
# ('rice_major', 'yield', '2003')	rows 9553	skip 249647
# ('rice_major', 'yield', '2004')	rows 9533	skip 249667
# ('rice_major', 'yield', '2005')	rows 9541	skip 249659
# ('rice_major', 'yield', '2006')	rows 9547	skip 249653
# ('rice_major', 'yield', '2007')	rows 9554	skip 249646
# ('rice_major', 'yield', '2008')	rows 9553	skip 249647
# ('rice_major', 'yield', '2009')	rows 9548	skip 249652
# ('rice_major', 'yield', '2010')	rows 9549	skip 249651
# ('rice_major', 'yield', '2011')	rows 8178	skip 251022
# ('rice_major', 'yield', '2012')	rows 8178	skip 251022
# ('rice_major', 'yield', '2013')	rows 8166	skip 251034
# ('rice_major', 'yield', '2014')	rows 8166	skip 251034
# ('rice_major', 'yield', '2015')	rows 7363	skip 251837
# ('rice_major', 'yield', '2016')	rows 8166	skip 251034
# ('rice_second', 'yield', '1981')	rows 467	skip 258733
# ('rice_second', 'yield', '1982')	rows 1587	skip 257613
# ('rice_second', 'yield', '1983')	rows 1587	skip 257613
# ('rice_second', 'yield', '1984')	rows 1587	skip 257613
# ('rice_second', 'yield', '1985')	rows 1587	skip 257613
# ('rice_second', 'yield', '1986')	rows 1587	skip 257613
# ('rice_second', 'yield', '1987')	rows 1587	skip 257613
# ('rice_second', 'yield', '1988')	rows 1587	skip 257613
# ('rice_second', 'yield', '1989')	rows 1585	skip 257615
# ('rice_second', 'yield', '1990')	rows 1587	skip 257613
# ('rice_second', 'yield', '1991')	rows 1586	skip 257614
# ('rice_second', 'yield', '1992')	rows 1587	skip 257613
# ('rice_second', 'yield', '1993')	rows 1587	skip 257613
# ('rice_second', 'yield', '1994')	rows 1587	skip 257613
# ('rice_second', 'yield', '1995')	rows 1587	skip 257613
# ('rice_second', 'yield', '1996')	rows 1587	skip 257613
# ('rice_second', 'yield', '1997')	rows 1587	skip 257613
# ('rice_second', 'yield', '1998')	rows 1587	skip 257613
# ('rice_second', 'yield', '1999')	rows 1587	skip 257613
# ('rice_second', 'yield', '2000')	rows 1587	skip 257613
# ('rice_second', 'yield', '2001')	rows 1587	skip 257613
# ('rice_second', 'yield', '2002')	rows 1587	skip 257613
# ('rice_second', 'yield', '2003')	rows 1587	skip 257613
# ('rice_second', 'yield', '2004')	rows 1587	skip 257613
# ('rice_second', 'yield', '2005')	rows 1587	skip 257613
# ('rice_second', 'yield', '2006')	rows 1587	skip 257613
# ('rice_second', 'yield', '2007')	rows 1587	skip 257613
# ('rice_second', 'yield', '2008')	rows 1587	skip 257613
# ('rice_second', 'yield', '2009')	rows 1587	skip 257613
# ('rice_second', 'yield', '2010')	rows 1587	skip 257613
# ('rice_second', 'yield', '2011')	rows 1507	skip 257693
# ('rice_second', 'yield', '2012')	rows 1507	skip 257693
# ('rice_second', 'yield', '2013')	rows 1507	skip 257693
# ('rice_second', 'yield', '2014')	rows 1507	skip 257693
# ('rice_second', 'yield', '2015')	rows 1408	skip 257792
# ('rice_second', 'yield', '2016')	rows 1507	skip 257693
# ('soybean', 'yield', '1981')	rows 2393	skip 256807
# ('soybean', 'yield', '1982')	rows 6109	skip 253091
# ('soybean', 'yield', '1983')	rows 6111	skip 253089
# ('soybean', 'yield', '1984')	rows 6108	skip 253092
# ('soybean', 'yield', '1985')	rows 6111	skip 253089
# ('soybean', 'yield', '1986')	rows 6108	skip 253092
# ('soybean', 'yield', '1987')	rows 6109	skip 253091
# ('soybean', 'yield', '1988')	rows 6123	skip 253077
# ('soybean', 'yield', '1989')	rows 6121	skip 253079
# ('soybean', 'yield', '1990')	rows 6118	skip 253082
# ('soybean', 'yield', '1991')	rows 6120	skip 253080
# ('soybean', 'yield', '1992')	rows 6121	skip 253079
# ('soybean', 'yield', '1993')	rows 6121	skip 253079
# ('soybean', 'yield', '1994')	rows 6116	skip 253084
# ('soybean', 'yield', '1995')	rows 6120	skip 253080
# ('soybean', 'yield', '1996')	rows 6120	skip 253080
# ('soybean', 'yield', '1997')	rows 6120	skip 253080
# ('soybean', 'yield', '1998')	rows 6123	skip 253077
# ('soybean', 'yield', '1999')	rows 6122	skip 253078
# ('soybean', 'yield', '2000')	rows 6121	skip 253079
# ('soybean', 'yield', '2001')	rows 6120	skip 253080
# ('soybean', 'yield', '2002')	rows 6121	skip 253079
# ('soybean', 'yield', '2003')	rows 6121	skip 253079
# ('soybean', 'yield', '2004')	rows 6119	skip 253081
# ('soybean', 'yield', '2005')	rows 6123	skip 253077
# ('soybean', 'yield', '2006')	rows 6122	skip 253078
# ('soybean', 'yield', '2007')	rows 6120	skip 253080
# ('soybean', 'yield', '2008')	rows 6122	skip 253078
# ('soybean', 'yield', '2009')	rows 6121	skip 253079
# ('soybean', 'yield', '2010')	rows 6120	skip 253080
# ('soybean', 'yield', '2011')	rows 5557	skip 253643
# ('soybean', 'yield', '2012')	rows 5557	skip 253643
# ('soybean', 'yield', '2013')	rows 5557	skip 253643
# ('soybean', 'yield', '2014')	rows 5557	skip 253643
# ('soybean', 'yield', '2015')	rows 4961	skip 254239
# ('soybean', 'yield', '2016')	rows 5557	skip 253643
# ('wheat', 'yield', '1981')	rows 2346	skip 256854
# ('wheat', 'yield', '1982')	rows 12628	skip 246572
# ('wheat', 'yield', '1983')	rows 12641	skip 246559
# ('wheat', 'yield', '1984')	rows 12627	skip 246573
# ('wheat', 'yield', '1985')	rows 12624	skip 246576
# ('wheat', 'yield', '1986')	rows 12655	skip 246545
# ('wheat', 'yield', '1987')	rows 12689	skip 246511
# ('wheat', 'yield', '1988')	rows 12712	skip 246488
# ('wheat', 'yield', '1989')	rows 12693	skip 246507
# ('wheat', 'yield', '1990')	rows 12700	skip 246500
# ('wheat', 'yield', '1991')	rows 12705	skip 246495
# ('wheat', 'yield', '1992')	rows 12705	skip 246495
# ('wheat', 'yield', '1993')	rows 12465	skip 246735
# ('wheat', 'yield', '1994')	rows 12710	skip 246490
# ('wheat', 'yield', '1995')	rows 12709	skip 246491
# ('wheat', 'yield', '1996')	rows 12701	skip 246499
# ('wheat', 'yield', '1997')	rows 12709	skip 246491
# ('wheat', 'yield', '1998')	rows 12731	skip 246469
# ('wheat', 'yield', '1999')	rows 12709	skip 246491
# ('wheat', 'yield', '2000')	rows 12704	skip 246496
# ('wheat', 'yield', '2001')	rows 12704	skip 246496
# ('wheat', 'yield', '2002')	rows 12702	skip 246498
# ('wheat', 'yield', '2003')	rows 12696	skip 246504
# ('wheat', 'yield', '2004')	rows 12695	skip 246505
# ('wheat', 'yield', '2005')	rows 12710	skip 246490
# ('wheat', 'yield', '2006')	rows 12709	skip 246491
# ('wheat', 'yield', '2007')	rows 12710	skip 246490
# ('wheat', 'yield', '2008')	rows 12712	skip 246488
# ('wheat', 'yield', '2009')	rows 12707	skip 246493
# ('wheat', 'yield', '2010')	rows 12705	skip 246495
# ('wheat', 'yield', '2011')	rows 10667	skip 248533
# ('wheat', 'yield', '2012')	rows 10667	skip 248533
# ('wheat', 'yield', '2013')	rows 10598	skip 248602
# ('wheat', 'yield', '2014')	rows 10598	skip 248602
# ('wheat', 'yield', '2015')	rows 9593	skip 249607
# ('wheat', 'yield', '2016')	rows 10598	skip 248602
# ('wheat_spring', 'yield', '1981')	rows 1255	skip 257945
# ('wheat_spring', 'yield', '1982')	rows 5119	skip 254081
# ('wheat_spring', 'yield', '1983')	rows 5122	skip 254078
# ('wheat_spring', 'yield', '1984')	rows 5119	skip 254081
# ('wheat_spring', 'yield', '1985')	rows 5123	skip 254077
# ('wheat_spring', 'yield', '1986')	rows 5123	skip 254077
# ('wheat_spring', 'yield', '1987')	rows 5123	skip 254077
# ('wheat_spring', 'yield', '1988')	rows 5123	skip 254077
# ('wheat_spring', 'yield', '1989')	rows 5125	skip 254075
# ('wheat_spring', 'yield', '1990')	rows 5118	skip 254082
# ('wheat_spring', 'yield', '1991')	rows 5116	skip 254084
# ('wheat_spring', 'yield', '1992')	rows 5120	skip 254080
# ('wheat_spring', 'yield', '1993')	rows 4876	skip 254324
# ('wheat_spring', 'yield', '1994')	rows 5123	skip 254077
# ('wheat_spring', 'yield', '1995')	rows 5121	skip 254079
# ('wheat_spring', 'yield', '1996')	rows 5122	skip 254078
# ('wheat_spring', 'yield', '1997')	rows 5126	skip 254074
# ('wheat_spring', 'yield', '1998')	rows 5129	skip 254071
# ('wheat_spring', 'yield', '1999')	rows 5125	skip 254075
# ('wheat_spring', 'yield', '2000')	rows 5125	skip 254075
# ('wheat_spring', 'yield', '2001')	rows 5126	skip 254074
# ('wheat_spring', 'yield', '2002')	rows 5127	skip 254073
# ('wheat_spring', 'yield', '2003')	rows 5129	skip 254071
# ('wheat_spring', 'yield', '2004')	rows 5123	skip 254077
# ('wheat_spring', 'yield', '2005')	rows 5122	skip 254078
# ('wheat_spring', 'yield', '2006')	rows 5126	skip 254074
# ('wheat_spring', 'yield', '2007')	rows 5121	skip 254079
# ('wheat_spring', 'yield', '2008')	rows 5125	skip 254075
# ('wheat_spring', 'yield', '2009')	rows 5116	skip 254084
# ('wheat_spring', 'yield', '2010')	rows 5119	skip 254081
# ('wheat_spring', 'yield', '2011')	rows 4165	skip 255035
# ('wheat_spring', 'yield', '2012')	rows 4165	skip 255035
# ('wheat_spring', 'yield', '2013')	rows 4159	skip 255041
# ('wheat_spring', 'yield', '2014')	rows 4159	skip 255041
# ('wheat_spring', 'yield', '2015')	rows 4073	skip 255127
# ('wheat_spring', 'yield', '2016')	rows 4159	skip 255041
# ('wheat_winter', 'yield', '1981')	rows 1091	skip 258109
# ('wheat_winter', 'yield', '1982')	rows 8569	skip 250631
# ('wheat_winter', 'yield', '1983')	rows 8579	skip 250621
# ('wheat_winter', 'yield', '1984')	rows 8568	skip 250632
# ('wheat_winter', 'yield', '1985')	rows 8562	skip 250638
# ('wheat_winter', 'yield', '1986')	rows 8593	skip 250607
# ('wheat_winter', 'yield', '1987')	rows 8627	skip 250573
# ('wheat_winter', 'yield', '1988')	rows 8650	skip 250550
# ('wheat_winter', 'yield', '1989')	rows 8630	skip 250570
# ('wheat_winter', 'yield', '1990')	rows 8642	skip 250558
# ('wheat_winter', 'yield', '1991')	rows 8649	skip 250551
# ('wheat_winter', 'yield', '1992')	rows 8645	skip 250555
# ('wheat_winter', 'yield', '1993')	rows 8644	skip 250556
# ('wheat_winter', 'yield', '1994')	rows 8648	skip 250552
# ('wheat_winter', 'yield', '1995')	rows 8650	skip 250550
# ('wheat_winter', 'yield', '1996')	rows 8640	skip 250560
# ('wheat_winter', 'yield', '1997')	rows 8645	skip 250555
# ('wheat_winter', 'yield', '1998')	rows 8664	skip 250536
# ('wheat_winter', 'yield', '1999')	rows 8646	skip 250554
# ('wheat_winter', 'yield', '2000')	rows 8641	skip 250559
# ('wheat_winter', 'yield', '2001')	rows 8640	skip 250560
# ('wheat_winter', 'yield', '2002')	rows 8636	skip 250564
# ('wheat_winter', 'yield', '2003')	rows 8629	skip 250571
# ('wheat_winter', 'yield', '2004')	rows 8632	skip 250568
# ('wheat_winter', 'yield', '2005')	rows 8648	skip 250552
# ('wheat_winter', 'yield', '2006')	rows 8644	skip 250556
# ('wheat_winter', 'yield', '2007')	rows 8649	skip 250551
# ('wheat_winter', 'yield', '2008')	rows 8648	skip 250552
# ('wheat_winter', 'yield', '2009')	rows 8649	skip 250551
# ('wheat_winter', 'yield', '2010')	rows 8647	skip 250553
# ('wheat_winter', 'yield', '2011')	rows 7389	skip 251811
# ('wheat_winter', 'yield', '2012')	rows 7389	skip 251811
# ('wheat_winter', 'yield', '2013')	rows 7319	skip 251881
# ('wheat_winter', 'yield', '2014')	rows 7319	skip 251881
# ('wheat_winter', 'yield', '2015')	rows 6309	skip 252891
# ('wheat_winter', 'yield', '2016')	rows 7319	skip 251881
